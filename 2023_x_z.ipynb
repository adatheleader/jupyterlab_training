# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
data_set = pd.read_csv('/Users/lydiakhashina/Downloads/2023_x_z.csv')
data_set.head()
# Out:
#                                                    x  \
# 0  -100891407805086093022027616949915903000574188...
# 1  -199627418134874752422397417487245009166383534...
# 2  -174137577873435496702358391578815658873753491...
# 3  -694185393282788030531734193747671936426126033...
# 4  -722633399409584755024789336376585898686414145...
#
#                                                    z
# 0  -860947309639333943274321868365016185214657598...
# 1  -425484590695713385927026324660869811421617629...
# 2  3602597763982979059024994335484889948017888179...
# 3  -283182982171635235446554136775837121853939357...
# 4  -586156210110036392915267186264316004278134108...

# %%
df = pd.DataFrame(data_set)


plt.scatter(df['x'], df['z'])
plt.show()
